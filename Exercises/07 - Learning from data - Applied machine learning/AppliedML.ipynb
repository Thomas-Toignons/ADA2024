# %% [markdown]
# ## All you need is love… And a pet!
#
# <img src="img/dataset-cover.jpg" width="920">
#
# Here we are going to build a classifier to predict whether an animal from an animal shelter will be adopted or not (aac_intakes_outcomes.csv, available at: https://www.kaggle.com/aaronschlegel/austin-animal-center-shelter-intakes-and-outcomes/version/1#aac_intakes_outcomes.csv). You will be working with the following features:
#
# 1. *animal_type:* Type of animal. May be one of 'cat', 'dog', 'bird', etc.
# 2. *intake_year:* Year of intake
# 3. *intake_condition:* The intake condition of the animal. Can be one of 'normal', 'injured', 'sick', etc.
# 4. *intake_number:* The intake number denoting the number of occurrences the animal has been brought into the shelter. Values higher than 1 indicate the animal has been taken into the shelter on more than one occasion.
# 5. *intake_type:* The type of intake, for example, 'stray', 'owner surrender', etc.
# 6. *sex_upon_intake:* The gender of the animal and if it has been spayed or neutered at the time of intake
# 7. *age_upon\_intake_(years):* The age of the animal upon intake represented in years
# 8. *time_in_shelter_days:* Numeric value denoting the number of days the animal remained at the shelter from intake to outcome.
# 9. *sex_upon_outcome:* The gender of the animal and if it has been spayed or neutered at time of outcome
# 10. *age_upon\_outcome_(years):* The age of the animal upon outcome represented in years
# 11. *outcome_type:* The outcome type. Can be one of ‘adopted’, ‘transferred’, etc.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
from itertools import combinations 
import ast
from sklearn.linear_model import LogisticRegression
import seaborn as sn
# %matplotlib inline

data_folder = './data/'

np.random.seed(2)
import helpers

# %% [markdown]
# ### A) Load the dataset and convert categorical features to a suitable numerical representation (use dummy-variable encoding).
# - Split the data into a training set (80%) and a test set (20%). Pair each feature vector with the corresponding label, i.e., whether the outcome_type is adoption or not.
# - Standardize the values of each feature in the data to have mean 0 and variance 1.
#
# The use of external libraries is not permitted in part A, except for numpy and pandas.
# You can drop entries with missing values.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
columns = ['animal_type', 'intake_year', 'intake_condition', 'intake_number', 'intake_type', 'sex_upon_intake', \
          'age_upon_intake_(years)', 'time_in_shelter_days', 'sex_upon_outcome', 'age_upon_outcome_(years)', \
          'outcome_type']
original_data = pd.read_csv(data_folder+'aac_intakes_outcomes.csv', usecols=columns)

# %%
print('The length of the data with all rows is : {}'.format(len(original_data)))
original_data.dropna(inplace=True)
print('The length of the data without the rows with nan value is: {}'.format(len(original_data)))
original_data.head(5)
# Out:
# The length of the data with all rows is : 79672
# The length of the data without the rows with nan value is: 79661
#       outcome_type sex_upon_outcome  age_upon_outcome_(years) animal_type  \
# 0  Return to Owner    Neutered Male                      10.0         Dog
# 1  Return to Owner    Neutered Male                       7.0         Dog
# 2  Return to Owner    Neutered Male                       6.0         Dog
# 3         Transfer    Neutered Male                      10.0         Dog
# 4  Return to Owner    Neutered Male                      16.0         Dog
#
#   intake_condition      intake_type sex_upon_intake  age_upon_intake_(years)  \
# 0           Normal            Stray   Neutered Male                     10.0
# 1           Normal    Public Assist   Neutered Male                      7.0
# 2           Normal    Public Assist   Neutered Male                      6.0
# 3           Normal  Owner Surrender   Neutered Male                     10.0
# 4          Injured    Public Assist   Neutered Male                     16.0
#
#    intake_year  intake_number  time_in_shelter_days
# 0         2017            1.0              0.588194
# 1         2014            2.0              1.259722
# 2         2014            3.0              1.113889
# 3         2014            1.0              4.970139
# 4         2013            1.0              0.119444

# %%
numerical_features = ['age_upon_outcome_(years)', 'age_upon_intake_(years)','intake_year', 'intake_number','time_in_shelter_days']
categorical_features = ['animal_type', 'intake_condition', 'intake_type', 'sex_upon_intake', 'sex_upon_outcome']
features = numerical_features + categorical_features

label = ['outcome_type']

# %%
# Create the feature dataset
X = original_data.copy().drop(columns=label)
X[numerical_features] = scaler.fit_transform(X[numerical_features])
X = pd.get_dummies(X, columns=categorical_features)

#for col in numerical_features:
#    X[col] = (X[col]-np.mean(X[col]))/np.std(X[col])

# Create the label dataset
y = original_data.copy()[label]
y['adopted'] = y.outcome_type.apply(lambda r: 1 if r=='Adoption' else 0)
y = y.drop(columns='outcome_type')

# %%
X.head(5)
# Out:
#    age_upon_outcome_(years)  age_upon_intake_(years)  intake_year  \
# 0                  2.709425                 2.727923     1.200112
# 1                  1.674948                 1.690977    -1.102055
# 2                  1.330123                 1.345329    -1.102055
# 3                  2.709425                 2.727923    -1.102055
# 4                  4.778379                 4.801813    -1.869444
#
#    intake_number  time_in_shelter_days  animal_type_Bird  animal_type_Cat  \
# 0      -0.278017             -0.387949             False            False
# 1       1.914763             -0.371838             False            False
# 2       4.107543             -0.375337             False            False
# 3      -0.278017             -0.282821             False            False
# 4      -0.278017             -0.399195             False            False
#
#    animal_type_Dog  animal_type_Other  intake_condition_Aged  ...  \
# 0             True              False                  False  ...
# 1             True              False                  False  ...
# 2             True              False                  False  ...
# 3             True              False                  False  ...
# 4             True              False                  False  ...
#
#    sex_upon_intake_Intact Female  sex_upon_intake_Intact Male  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
#
#    sex_upon_intake_Neutered Male  sex_upon_intake_Spayed Female  \
# 0                           True                          False
# 1                           True                          False
# 2                           True                          False
# 3                           True                          False
# 4                           True                          False
#
#    sex_upon_intake_Unknown  sex_upon_outcome_Intact Female  \
# 0                    False                           False
# 1                    False                           False
# 2                    False                           False
# 3                    False                           False
# 4                    False                           False
#
#    sex_upon_outcome_Intact Male  sex_upon_outcome_Neutered Male  \
# 0                         False                            True
# 1                         False                            True
# 2                         False                            True
# 3                         False                            True
# 4                         False                            True
#
#    sex_upon_outcome_Spayed Female  sex_upon_outcome_Unknown
# 0                           False                     False
# 1                           False                     False
# 2                           False                     False
# 3                           False                     False
# 4                           False                     False
#
# [5 rows x 32 columns]

# %%
df = original_data.copy()
df[numerical_features] = scaler.fit_transform(df[numerical_features])
df = pd.get_dummies(df,columns=categorical_features)
df['adopted'] = df.outcome_type.apply(lambda r: 1 if r=='Adoption' else 0)
df = df.drop(columns=label)

df.head(5)
# Out:
#    age_upon_outcome_(years)  age_upon_intake_(years)  intake_year  \
# 0                  2.709425                 2.727923     1.200112
# 1                  1.674948                 1.690977    -1.102055
# 2                  1.330123                 1.345329    -1.102055
# 3                  2.709425                 2.727923    -1.102055
# 4                  4.778379                 4.801813    -1.869444
#
#    intake_number  time_in_shelter_days  animal_type_Bird  animal_type_Cat  \
# 0      -0.278017             -0.387949             False            False
# 1       1.914763             -0.371838             False            False
# 2       4.107543             -0.375337             False            False
# 3      -0.278017             -0.282821             False            False
# 4      -0.278017             -0.399195             False            False
#
#    animal_type_Dog  animal_type_Other  intake_condition_Aged  ...  \
# 0             True              False                  False  ...
# 1             True              False                  False  ...
# 2             True              False                  False  ...
# 3             True              False                  False  ...
# 4             True              False                  False  ...
#
#    sex_upon_intake_Intact Male  sex_upon_intake_Neutered Male  \
# 0                        False                           True
# 1                        False                           True
# 2                        False                           True
# 3                        False                           True
# 4                        False                           True
#
#    sex_upon_intake_Spayed Female  sex_upon_intake_Unknown  \
# 0                          False                    False
# 1                          False                    False
# 2                          False                    False
# 3                          False                    False
# 4                          False                    False
#
#    sex_upon_outcome_Intact Female  sex_upon_outcome_Intact Male  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                           False                         False
#
#    sex_upon_outcome_Neutered Male  sex_upon_outcome_Spayed Female  \
# 0                            True                           False
# 1                            True                           False
# 2                            True                           False
# 3                            True                           False
# 4                            True                           False
#
#    sex_upon_outcome_Unknown  adopted
# 0                     False        0
# 1                     False        0
# 2                     False        0
# 3                     False        0
# 4                     False        0
#
# [5 rows x 33 columns]

# %% [raw]
# X_train, y_train, X_test, y_test = helpers.preprocess_data(df, label="adopted", train_size=0.8, seed=2)

# %%
#Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=52)

# Display the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

X_train.sort_index(ascending=False).head(5)
# Out:
# X_train shape: (63728, 32)
# X_test shape: (15933, 32)
# y_train shape: (63728, 1)
# y_test shape: (15933, 1)
#        age_upon_outcome_(years)  age_upon_intake_(years)  intake_year  \
# 79671                  2.709425                 2.727923     1.967501
# 79670                 -0.455413                -0.586514     1.967501
# 79669                 -0.394006                -0.382913     1.967501
# 79668                 -0.049180                -0.037265     1.967501
# 79667                 -0.725605                -0.715304     1.967501
#
#        intake_number  time_in_shelter_days  animal_type_Bird  animal_type_Cat  \
# 79671      -0.278017             -0.382535             False            False
# 79670      -0.278017             -0.359776             False            False
# 79669      -0.278017             -0.400911             False            False
# 79668      -0.278017             -0.400778             False            False
# 79667      -0.278017             -0.400212             False             True
#
#        animal_type_Dog  animal_type_Other  intake_condition_Aged  ...  \
# 79671             True              False                   True  ...
# 79670             True              False                  False  ...
# 79669            False               True                  False  ...
# 79668            False               True                  False  ...
# 79667            False              False                  False  ...
#
#        sex_upon_intake_Intact Female  sex_upon_intake_Intact Male  \
# 79671                          False                        False
# 79670                          False                         True
# 79669                          False                        False
# 79668                          False                        False
# 79667                          False                        False
#
#        sex_upon_intake_Neutered Male  sex_upon_intake_Spayed Female  \
# 79671                          False                           True
# 79670                          False                          False
# 79669                          False                          False
# 79668                          False                          False
# 79667                          False                          False
#
#        sex_upon_intake_Unknown  sex_upon_outcome_Intact Female  \
# 79671                    False                           False
# 79670                    False                           False
# 79669                     True                           False
# 79668                     True                           False
# 79667                     True                           False
#
#        sex_upon_outcome_Intact Male  sex_upon_outcome_Neutered Male  \
# 79671                         False                           False
# 79670                          True                           False
# 79669                         False                           False
# 79668                         False                           False
# 79667                         False                           False
#
#        sex_upon_outcome_Spayed Female  sex_upon_outcome_Unknown
# 79671                            True                     False
# 79670                           False                     False
# 79669                           False                      True
# 79668                           False                      True
# 79667                           False                      True
#
# [5 rows x 32 columns]

# %% [markdown]
# ### B) Train a logistic regression classifier on your training set. Logistic regression returns probabilities as predictions, so in order to arrive at a binary prediction, you need to put a threshold on the predicted probabilities.
# - For the decision threshold of 0.5, present the performance of your classifier on the test set by displaying the confusion matrix. Based on the confusion matrix, manually calculate accuracy, precision, recall, and F1-score with respect to the positive and the negative class.

# %%
from sklearn.metrics import confusion_matrix
def confusion_matrix_scorer(clf, X, y):
     y_pred = clf.predict(X)
     cm = confusion_matrix(y, y_pred)
     return {'tn': cm[0, 0], 'fp': cm[0, 1],
             'fn': cm[1, 0], 'tp': cm[1, 1]}

# %%
logistic = LogisticRegression()
logistic.fit(X_train, y_train)
prediction = logistic.predict_proba(X_test)
prediction = [1 if x[1] > 0.5 else 0 for x in prediction]
confusion_matrix_scorer(logistic, X_test, y_test)
# Out:
# c:\Users\thoma\AppData\Local\anaconda3\envs\ada\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'tn': 7526, 'fp': 1665, 'fn': 1170, 'tp': 5572}

# %% [markdown]
# ### C) Vary the value of the threshold in the range from 0 to 1 and visualize the value of accuracy, precision, recall, and F1-score (with respect to both classes) as a function of the threshold.

# %% [markdown]
# ### D) Plot in a bar chart the coefficients of the logistic regression sorted by their contribution to the prediction.

# %%
tmp = []
for name, value in zip(X_train.columns, logistic.coef_[0]):
    tmp.append({"name": name, "value": value})
    
features_coef = pd.DataFrame(tmp).sort_values("value")
features_coef.head()
# Out:
#                               name     value
# 21            intake_type_Wildlife -1.838121
# 28    sex_upon_outcome_Intact Male -1.834580
# 1          age_upon_intake_(years) -1.773835
# 10          intake_condition_Feral -1.643686
# 27  sex_upon_outcome_Intact Female -1.640864

# %%
plt.subplots(figsize=(5,7))
plt.barh(features_coef.name, features_coef.value, alpha=0.6)
# Out:
# <BarContainer object of 32 artists>

# %% [markdown]
# ## Question 1: Which of the following metrics is most suitable when you are dealing with unbalanced classes?
#
# - a) F1 Score
# - b) Recall
# - c) Precision
# - d) Accuracy

# %% [markdown]
# ## Question 2: You are working on a binary classification problem. You trained a model on a training dataset and got the following confusion matrix on the test dataset. What is true about the evaluation metrics (rounded to the second decimal point):
#
# |            | Pred = NO|Pred=YES|
# |------------|----------|--------|
# | Actual NO  |    50    |   10   |
# | Actual YES |    5     |   100  |
#
# - a) Accuracy is 0.95
# - b) Accuracy is 0.85
# - c) False positive rate is 0.95
# - d) True positive rate is 0.95
